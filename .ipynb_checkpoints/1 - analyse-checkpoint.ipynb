# %% [markdown]
# Imports des librairies

# %%
import pandas as pd

# %% [markdown]
# Première analyse des fichiers

# %%
# Dossier contenant les fichiers CSV
dossier = 'data/'

# Liste des années à vérifier
annees = list(range(2005, 2023))

# Liste des types de fichiers à lire
types_fichiers = ['caracteristiques', 'lieux', 'usagers', 'vehicules', 'vehicules-immatricules-baac']

# Initialisation de la liste pour stocker les résultats d'analyse
resultats_analyse = []

# Fonction pour lire les fichiers et extraire les informations
def analyser_fichier(chemin_fichier, type_fichier, annee):
    separateurs = [',', ';', '\t']
    for sep in separateurs:
        try:
            df = pd.read_csv(chemin_fichier, encoding='ISO-8859-1', delimiter=sep, on_bad_lines='skip')
            if len(df.columns) > 1:
                return {
                    'nom_fichier': f'{type_fichier}_{annee}.csv',
                    'nombre_colonnes': len(df.columns),
                    'nombre_lignes': len(df),
                    'colonnes': df.columns.tolist(),
                    'statut': 'Succès',
                    'separateur': sep
                }
        except Exception:
            continue
    return {
        'nom_fichier': f'{type_fichier}_{annee}.csv',
        'nombre_colonnes': 1,
        'nombre_lignes': 0,
        'colonnes': [],
        'statut': 'Échec de lecture',
        'separateur': 'N/A'
    }

# Analyse des fichiers et stockage des résultats
for type_fichier in types_fichiers:
    for annee in annees:
        chemin_fichier = f'{dossier}{type_fichier}_{annee}.csv'
        resultat = analyser_fichier(chemin_fichier, type_fichier, annee)
        resultat['type_fichier'] = type_fichier
        resultat['annee'] = annee
        resultats_analyse.append(resultat)

# Création d'un DataFrame pour les résultats d'analyse
analyse_df = pd.DataFrame(resultats_analyse)

# Export des résultats d'analyse en fichier Excel
#with pd.ExcelWriter('resultats_analyse.xlsx') as writer:
#    analyse_df.to_excel(writer, sheet_name='Résultats Analyse', index=False)

print("Export terminé.")

# %%
analyse_df.head(30)
# Out:
#                   nom_fichier  nombre_colonnes  nombre_lignes  \
# 0   caracteristiques_2005.csv               16          87026
# 1   caracteristiques_2006.csv               16          82993
# 2   caracteristiques_2007.csv               16          83850
# 3   caracteristiques_2008.csv               16          76767
# 4   caracteristiques_2009.csv               16          74409
# 5   caracteristiques_2010.csv               16          69379
# 6   caracteristiques_2011.csv               16          66974
# 7   caracteristiques_2012.csv               16          62250
# 8   caracteristiques_2013.csv               16          58397
# 9   caracteristiques_2014.csv               16          59854
# 10  caracteristiques_2015.csv               16          58654
# 11  caracteristiques_2016.csv               16          59432
# 12  caracteristiques_2017.csv               16          60701
# 13  caracteristiques_2018.csv               16          57783
# 14  caracteristiques_2019.csv               15          58840
# 15  caracteristiques_2020.csv               15          47744
# 16  caracteristiques_2021.csv               15          56518
# 17  caracteristiques_2022.csv               15          55302
# 18             lieux_2005.csv               18          87026
# 19             lieux_2006.csv               18          82993
# 20             lieux_2007.csv               18          83850
# 21             lieux_2008.csv               18          76767
# 22             lieux_2009.csv               18          74409
# 23             lieux_2010.csv               18          69379
# 24             lieux_2011.csv               18          66974
# 25             lieux_2012.csv               18          62250
# 26             lieux_2013.csv               18          58397
# 27             lieux_2014.csv               18          59854
# 28             lieux_2015.csv               18          58654
# 29             lieux_2016.csv               18          59432
#
#                                              colonnes  statut separateur  \
# 0   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 1   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 2   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 3   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 4   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès         \t
# 5   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 6   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 7   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 8   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 9   [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 10  [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 11  [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 12  [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 13  [Num_Acc, an, mois, jour, hrmn, lum, agg, int,...  Succès          ,
# 14  [Num_Acc, jour, mois, an, hrmn, lum, dep, com,...  Succès          ;
# 15  [Num_Acc, jour, mois, an, hrmn, lum, dep, com,...  Succès          ;
# 16  [Num_Acc, jour, mois, an, hrmn, lum, dep, com,...  Succès          ;
# 17  [Accident_Id, jour, mois, an, hrmn, lum, dep, ...  Succès          ;
# 18  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 19  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 20  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 21  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 22  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 23  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 24  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 25  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 26  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 27  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 28  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
# 29  [Num_Acc, catr, voie, v1, v2, circ, nbv, pr, p...  Succès          ,
#
#         type_fichier  annee
# 0   caracteristiques   2005
# 1   caracteristiques   2006
# 2   caracteristiques   2007
# 3   caracteristiques   2008
# 4   caracteristiques   2009
# 5   caracteristiques   2010
# 6   caracteristiques   2011
# 7   caracteristiques   2012
# 8   caracteristiques   2013
# 9   caracteristiques   2014
# 10  caracteristiques   2015
# 11  caracteristiques   2016
# 12  caracteristiques   2017
# 13  caracteristiques   2018
# 14  caracteristiques   2019
# 15  caracteristiques   2020
# 16  caracteristiques   2021
# 17  caracteristiques   2022
# 18             lieux   2005
# 19             lieux   2006
# 20             lieux   2007
# 21             lieux   2008
# 22             lieux   2009
# 23             lieux   2010
# 24             lieux   2011
# 25             lieux   2012
# 26             lieux   2013
# 27             lieux   2014
# 28             lieux   2015
# 29             lieux   2016
